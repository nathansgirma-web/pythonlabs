# %% [markdown]
# # Lab 1 - Problems
# **Basics of numpy and matplotlib**<br>
# Software 1 - Mathematics<br>
# Information and Communication Technology<br>
# Metropolia University of Applied Sciences

# %% [markdown]
# ## Setup

# %%
name = "Nathan Girma" # Write your name between the parenthesis
student_id =  2519029 # Change your student ID here
date_returned = "" # Write the date returned between the parenthesis

# %%
from IPython.display import Markdown, display # IPython.display is used to display Markdown text in Jupyter notebooks
import numpy as np # numpy is used for numerical calculations
import matplotlib.pyplot as plt # matplotlib is used for plotting graphics
import labx as mx # Remember to download labx module from OMA assignment !!!

# %% [markdown]
# ---
# ## My solution for problem 1

# %%
# Define x and calculate y
x = np.arange(-10,10.001,0.001)
y = mx.lab_1_problem_1(x,  2519029)
# Make a graph of y(x)
plt.figure(figsize=(5, 3))
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.title("Lab 1 Problems (1)")
plt.legend(["x", "y"])
plt.show()


plt.show()

# %% [markdown]
# ---
# ## My solution for problem 2

# %%
plt.figure(figsize=(5,3))
plt.plot(x, y)
plt.xlim(-2, 2)
plt.ylim(-1, 1)
plt.axhline(0, color='red', linestyle='--')
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(['x', 'f(x)'])

plt.show()

# %% [markdown]
# ---
# ## Extras
#
# ### Solution 3 (extra)

# %%
# As this is an extra challenge, you are on your own. Write your code here.

# %% [markdown]
# ### Solution 4 (extra)

# %%
# Your code comes here. Again, as this is extra, you are on your own.
# As this is an extra challenge, you are on your own. Write your code here.
